# %% [markdown]
# # Project - Test a Perceptual Phenomenon

# %% [markdown]
# ## Background Information
# In a Stroop task, participants are presented with a list of words, with each word displayed in a color of ink. The participant’s task is to say out loud the color of the ink in which the word is printed. The task has two conditions: a congruent words condition, and an incongruent words condition. In the congruent words condition, the words being displayed are color words whose names match the colors in which they are printed: for example RED, BLUE. In the incongruent words condition, the words displayed are color words whose names do not match the colors in which they are printed: for example PURPLE, ORANGE. In each case, we measure the time it takes to name the ink colors in equally-sized lists. Each participant will go through and record a time from each condition.

# %% [markdown]
# ### Questions For Investigation
# As a general note, be sure to keep a record of any resources that you use or refer to in the creation of your project. You will need to report your sources as part of the project submission.

# %% [markdown]
# **1. What is our independent variable? What is our dependent variable?**
#
# *Answer:*
#
# * Independent Variable: Two conditions - Congurent words and Incongruent words.
#
# * Dependent Variable: Time Taken for each condition.

# %% [markdown]
# **2. What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.**
#
# *Answer*
#
# **1. a)Hypotheses**
#
# **H**0 - Time record is equal in both conditions (Not Significant).
#
# __µ__ congruent = **µ** incongruent
#
# **H**a - Time record is not equal in both conditions (Significant).
#
# **µ** congruent ≠ **µ** incongruent
#
# Where,
#
# - __µ__ congruent = Population mean of congruent words test
# - __µ__ incongruent = Population mean of incongruent words test
#
# **2. b)Kind of Statistical Test**
#
# - _Two Tailed t-Test._
#
# **3. c)Justify**
#
# We're comparing the reaction time of samples for two different conditions of same population. Hence coming to a conclusion to use t-Test. Also population is less than 30.

# %% [markdown]
# *Now it’s your chance to try out the Stroop task for yourself. Go to this link, which has a Java-based applet for performing the Stroop task. Record the times that you received on the task (you do not need to submit your times to the site.) Now, download this dataset which contains results from a number of participants in the task. Each row of the dataset contains the performance for one participant, with the first number their results on the congruent task and the second number their performance on the incongruent task.*

# %% [markdown]
# **3. Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.**
#
# *Answer*

# %% [markdown]
# | Tests         | MEAN          | Median | Standard Deviation  |
# | ------------- |:-------------:|--------| -------------------:|
# | Congruent     |     14.05     |  14.09 |        3.56         |
# | Incongruent   |     22.02     |  21.32 |        4.80         |
#
#
# _Answers above calculated using google sheets. File attached to this project_ "Stroopdata_report.xlsx"

# %% [markdown]
# **4. Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.**
#
# *Answer*

# %% [markdown]
# __Congruent__
#
# ![01.PNG](attachment:01.PNG)
#
# __Incongruent__
#
# ![02.PNG](attachment:02.PNG)
#
# ___By observing the plots, we can easily notice there is a significant time difference (in seconds) for incongruent test is bigger than the congruent histogram.___
#
# Participants took less than 30 seconds in congruent condition, but in incongruent it took upto 40 seconds to complete the test.

# %% [markdown]
# **5. Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?**
#
# *Answer*
#
# __Population Size (n)__ = 24
#
# __Degrees of Freedom__ = 23
#
# __Alpha Level α__ = 0.05
#
# __t-Critical__ = 2.069
#
# __Mean µ Difference__ = -7.96
#
# __SEM (Standard Error of Mean)__ = 1.22
#
# __Confidence Interval (95%)__ = -10.52, -5.44
#
# Since the p-value is less than 0.025, we __reject__ the null hypothesis __H__0.
#
# And therefore there is a significant time difference in two conditions. And yes, the results match up with my expectations.

# %% [markdown]
# **6. Optional: What do you think is responsible for the effects observed? Can you think of an alternative or similar task that would result in a similar effect? Some research about the problem will be helpful for thinking about these two questions!**
#
#     *Answer*
#
# __Responsible for Effects Observed__
#
# Assuming our brain sees the world using two techniques reading and pattern/shape reconginition. It's easy when a text named "Yellow" is colored in yellow. It helps both visually and what it is mapped to. __Congruent__
#
# When a text named "RED" and coloured in blue, because of differently mapped, It takes some extra time to process. __Incongruent__
